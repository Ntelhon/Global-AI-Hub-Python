# %% [markdown]
# <a href="https://colab.research.google.com/github/Ntelhon/Global-AI-Hub-Python/blob/main/Global_AI_Hub_Python_Homework4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Furkan Karabulut
#29/05/2021
#Global AI Hub Python Course HomeWork 4

def drawLine(skor=0):
  print("----------------------------------------------------------")
  if not skor==0: print(f"Mevcut Skorun {skor}")
  print("----------------------------------------------------------")

again = True
while again:
  skor = 0
  name = input("Adınız? ")
  print(f"Merhaba {name}, Bilgi Yarışmamıza Hoş Geldiniz!!!")
  print("Yarışmamız her biri 10 puan değerinde 10 sorudan oluşmaktadır.")
  print("Başarılı olmak için en az 60 puan toplaman gerekiyor.")
  print("Çoktan seçmeli sorulara cevap vermek için seçtiğin şıkkı yazman yeterli.")
  start = input("Başlamak için herhangi bir tuşa tıklayın! ")
  drawLine()

  print("1. Soru")
  print("Python dile ile yazılmış bir dosyanın uzantısının ne olması beklenir? (example.xxx)")
  a1 = input("Cevabınız? ")
  if a1 == ".py" or a1 =="py": skor+=10; print("DOĞRU Cevap")
  else: print("Malesef cevabın yanlış, doğru cevap: py")
  drawLine(skor)

  print("2. Soru")
  print("Aklından bir sayı tutmasını istediğiniz arkadaşınız \"0x\" ile başlayan bir sayı tutmuşsa kaçlık tabanda bir sayı tutmuştur?")
  a2 = input("Cevabınız? ")
  if a2 == "16" or a2 == "on altı": skor+=10; print("DOĞRU Cevap")
  else: print("Malesef cevabın yanlış, doğru cevap: 16")
  drawLine(skor)

  print("3. Soru")
  print("Su molekülünün bileşenlerinden bir tanesini yazınız")
  a3 = input("Cevabınız? ")
  if a3 == "H" or a3 =="O" or a3 =="Hidrojen" or a3 =="hidrojen" or a3 =="Oksijen" or a3 =="oksijen": skor+=10; print("DOĞRU Cevap")
  else: print("Malesef cevabın yanlış, doğru cevap: Hidrojen ya da Oksijen")
  drawLine(skor)

  print("4. Soru")
  print("Dünya Sağlık Örgütünün kısaltması nedir?")
  a4 = input("Cevabınız? ")
  if a4 == "WHO": skor+=10; print("DOĞRU Cevap")
  else: print("Malesef cevabın yanlış, doğru cevap: WHO")
  drawLine(skor)

  print("5. Soru")
  print("5 karbonlu (5C) şekerlere bir örnek veriniz")
  a5 = input("Cevabınız? ")
  if a5 == "Riboz" or a5 =="Deoksiriboz" or a5 =="riboz" or a5 =="deoksiriboz": skor+=10; print("DOĞRU Cevap")
  else: print("Malesef cevabın yanlış, doğru cevap: Riboz ya da Deoksiriboz")
  drawLine(skor)

  sixT = False
  print("6. Soru")
  print("Fizikteki temel kuvvetlerden etki alanı sınırsız kabul edilen bir tanesini yazınız.")
  a6 = input("Cevabınız? ")
  c6_1 = "Kütle Çekim Kuvveti"
  c6_11 = "Kütle Çekim"
  c6_2 = "Elektromanyetik Kuvvet"
  if a6 == c6_1 or a6 ==c6_2 or a6 ==c6_1.lower or a6 ==c6_2.lower or a6 ==c6_11 or a6 ==c6_11.lower: skor+=10; print("DOĞRU Cevap"); sixT = True
  else: print("Malesef cevabın yanlış, doğru cevap: kütle çekim kuvveti ya da elektromanyetik kuvvet"); sixt = False
  drawLine(skor)

  print("7. Soru")
  print("Eğer bu soru 6. sorudan hemen önce sorulmuş ve de her soru 15 puan olsaydı bu soruyu doğru cevapladığında toplam kaç puannın olması gerekirdi?")
  a7 = input("Cevabınız? ")
  c7 = 0
  if sixT: c7 = int((skor-10) * 1.5)
  else: c7 = int(skor * 1.5)
  if a7 == str(c7): skor+=10; print("DOĞRU Cevap")
  else: print(f"Malesef cevabın yanlış, doğru cevap: {c7}")
  drawLine(skor)

  print("8. Soru")
  print("\"Kotlin'in yeni özelliklerini beğendin mi?\" sorusuna \"Görmedim bile, ben Flutterciyim.\" diyen biri muhtemelen hangi dille program(lar) yazıyordur?")
  a8 = input("Cevabınız? ")
  if a8 == "DART" or a8 =="dart" or a8 =="Dart": skor+=10; print("DOĞRU Cevap")
  else: print("Malesef cevabın yanlış, doğru cevap: Dart")
  drawLine(skor)

  print("9. Soru")
  print("Hangisi uzun burnu diğerlerinden ayrılan bir hayvandır?")
  print("a) Aslan     b) Misk Öküzü     c) Karıncayiyen     d) Zürafa")
  a9 = input("Cevabınız? ")
  if a9 == "c" or a9 =="c": skor+=10; print("DOĞRU Cevap")
  else: print("Malesef cevabın yanlış, doğru cevap: c")
  drawLine(skor)

  print("10. Soru")
  print("Bu şu ana kadar bu kodu yazan kişi tarafından yazılan en uzun python kodudur.")
  print("a) Doğru     b) Yanlış")
  a10 = input("Cevabınız? ")
  if a10 == "a" or a10 =="A": skor+=10; print("DOĞRU Cevap")
  else: print("Malesef cevabın yanlış, doğru cevap: a")
  drawLine()

  if skor > 59: print(f"Tebrikler!!  Yarışmayı kazandınız. Toplam Skorunuz: {skor}")
  else: print(f"Malesef kazanamadınız. Toplam Skorunuz: {skor}")
  lastInput = input("Tekrar oynamak için \"E\" ye basınız.")
  if lastInput == "E" or lastInput =="e":
    again = True
  else:
    again = False
# Out:
# Adınız? Furkan
# Merhaba Furkan, Bilgi Yarışmamıza Hoş Geldiniz!!!
# Yarışmamız her biri 10 puan değerinde 10 sorudan oluşmaktadır.
# Başarılı olmak için en az 60 puan toplaman gerekiyor.
# Çoktan seçmeli sorulara cevap vermek için seçtiğin şıkkı yazman yeterli.
# Başlamak için herhangi bir tuşa tıklayın! ğ
# ----------------------------------------------------------
# ----------------------------------------------------------
# 1. Soru
# Python dile ile yazılmış bir dosyanın uzantısının ne olması beklenir? (example.xxx)
# Cevabınız? py
# DOĞRU Cevap
# ----------------------------------------------------------
# Mevcut Skorun 10
# ----------------------------------------------------------
# 2. Soru
# Aklından bir sayı tutmasını istediğiniz arkadaşınız "0x" ile başlayan bir sayı tutmuşsa kaçlık tabanda bir sayı tutmuştur?
# Cevabınız? 16
# DOĞRU Cevap
# ----------------------------------------------------------
# Mevcut Skorun 20
# ...
